# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta


import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data = pd.read_csv('burglaries_preprocessed.csv')
data = data[['Month', 'Ward']]#, 'Season']]

# %%
data
# Out:
#          Month         Ward
# 0      2010-12  High Barnet
# 1      2010-12  High Barnet
# 2      2010-12  High Barnet
# 3      2010-12  High Barnet
# 4      2010-12  High Barnet
# ...        ...          ...
# 42986  2023-03  Childs Hill
# 42987  2023-03  Childs Hill
# 42988  2023-03  Childs Hill
# 42989  2023-03  Childs Hill
# 42990  2023-03  Childs Hill
#
# [42991 rows x 2 columns]

# %%
def reg_evaluation(y_test, y_pred, ward: str):    
    print(f'Results for {ward}:')
    print('Mean Absolute Error:', round(mean_absolute_error(y_test, y_pred),2))
    print('Root Mean Squared Error:', round(np.sqrt(mean_squared_error(y_test, y_pred)),2))
#     print('R2 score:', round(r2_score(y_test, y_pred),2))
    print('Weighted mean absolute percentage error:', 
          round(np.abs(y_test - y_pred).sum() / np.abs(y_test).sum(),2))
    print('\n')

# %% [markdown]
# ### Fix the imputation below after adding features!!

# %%
def create_features(df):
    '''set index to datetime, create temporal features
    '''

    df = df.set_index('Month')
    df.index = pd.to_datetime(df.index)
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['crime_count'] = 1
    
    return df

data = create_features(data)

# %%
def return_year_month(row): 
    '''created for convenience later on
    '''
    return str(row['year']) + '-' + str(row['month'])

# %%
data
# Out:
#                    Ward  month  year  crime_count
# Month
# 2010-12-01  High Barnet     12  2010            1
# 2010-12-01  High Barnet     12  2010            1
# 2010-12-01  High Barnet     12  2010            1
# 2010-12-01  High Barnet     12  2010            1
# 2010-12-01  High Barnet     12  2010            1
# ...                 ...    ...   ...          ...
# 2023-03-01  Childs Hill      3  2023            1
# 2023-03-01  Childs Hill      3  2023            1
# 2023-03-01  Childs Hill      3  2023            1
# 2023-03-01  Childs Hill      3  2023            1
# 2023-03-01  Childs Hill      3  2023            1
#
# [42991 rows x 4 columns]

# %%
data_aggr = data.groupby(['year', 'month', 'Ward']).count()
data_aggr.reset_index(inplace=True)

# aggregate to get crimes per month, per ward in each row

# %%
data_aggr.loc[450:500]
# Out:
#      year  month                   Ward  crime_count
# 450  2012      6  Totteridge & Woodside           12
# 451  2012      6              Underhill           21
# 452  2012      6          West Finchley           23
# 453  2012      6            West Hendon           16
# 454  2012      6              Whetstone           19
# 455  2012      6              Woodhouse           27
# 456  2012      7            Barnet Vale           12
# 457  2012      7         Brunswick Park           10
# 458  2012      7              Burnt Oak           19
# 459  2012      7            Childs Hill           26
# 460  2012      7        Colindale North            4
# 461  2012      7        Colindale South            4
# 462  2012      7            Cricklewood            5
# 463  2012      7            East Barnet           22
# 464  2012      7          East Finchley            6
# 465  2012      7                Edgware           12
# 466  2012      7            Edgwarebury            8
# 467  2012      7    Finchley Church End           18
# 468  2012      7          Friern Barnet           19
# 469  2012      7          Garden Suburb           20
# 470  2012      7          Golders Green           21
# 471  2012      7                 Hendon           15
# 472  2012      7            High Barnet           14
# 473  2012      7              Mill Hill           22
# 474  2012      7  Totteridge & Woodside           13
# 475  2012      7              Underhill           10
# 476  2012      7          West Finchley           17
# 477  2012      7            West Hendon           14
# 478  2012      7              Whetstone           12
# 479  2012      7              Woodhouse           11
# 480  2012      8            Barnet Vale           16
# 481  2012      8         Brunswick Park           10
# 482  2012      8              Burnt Oak           27
# 483  2012      8            Childs Hill           27
# 484  2012      8        Colindale North            6
# 485  2012      8        Colindale South            5
# 486  2012      8            Cricklewood            6
# 487  2012      8            East Barnet           19
# 488  2012      8          East Finchley           23
# 489  2012      8                Edgware           27
# 490  2012      8            Edgwarebury           14
# 491  2012      8    Finchley Church End           20
# 492  2012      8          Friern Barnet           27
# 493  2012      8          Garden Suburb            8
# 494  2012      8          Golders Green           18
# 495  2012      8                 Hendon           28
# 496  2012      8            High Barnet           16
# 497  2012      8              Mill Hill            9
# 498  2012      8  Totteridge & Woodside            2
# 499  2012      8              Underhill            9
# 500  2012      8          West Finchley           16

# %%
data_aggr['year_month'] = data_aggr.apply(return_year_month, axis=1)
data_aggr['date'] = data_aggr['year_month']
data_aggr = data_aggr.set_index('date')
data_aggr.index = pd.to_datetime(data_aggr.index)

# %%
data_aggr
# Out:
#             year  month             Ward  crime_count year_month
# date
# 2010-12-01  2010     12      Barnet Vale           13    2010-12
# 2010-12-01  2010     12   Brunswick Park           13    2010-12
# 2010-12-01  2010     12        Burnt Oak            9    2010-12
# 2010-12-01  2010     12      Childs Hill           17    2010-12
# 2010-12-01  2010     12  Colindale North            7    2010-12
# ...          ...    ...              ...          ...        ...
# 2023-03-01  2023      3        Underhill            1     2023-3
# 2023-03-01  2023      3    West Finchley           13     2023-3
# 2023-03-01  2023      3      West Hendon            9     2023-3
# 2023-03-01  2023      3        Whetstone            4     2023-3
# 2023-03-01  2023      3        Woodhouse            7     2023-3
#
# [3545 rows x 5 columns]

# %% [markdown]
# # Imputation of months w/o crime data

# %%
# collect the wards with a missing month

wards_wo_month = []

for month in data_aggr['Ward'].unique():
    if data_aggr[data_aggr['Ward']==month].shape[0]<148:        
        wards_wo_month.append(month)

# %%
# get the missing month for each of the wards

all_months = data_aggr.index.unique().to_list()
dct_impute = {}

for ward in wards_wo_month:
    
    lst_months=[]
    
    for i, row in data_aggr[data_aggr['Ward']==ward].iterrows():
        lst_months.append(i)
        dct_impute[ward] = list(set(all_months) - set(lst_months))[0]

# %%
dct_impute
# Out:
# {'Colindale North': Timestamp('2014-12-01 00:00:00'),
#  'Colindale South': Timestamp('2016-10-01 00:00:00'),
#  'Edgwarebury': Timestamp('2021-07-01 00:00:00'),
#  'High Barnet': Timestamp('2022-12-01 00:00:00'),
#  'Totteridge & Woodside': Timestamp('2021-05-01 00:00:00'),
#  'Whetstone': Timestamp('2023-01-01 00:00:00'),
#  'Woodhouse': Timestamp('2020-08-01 00:00:00')}

# %%
data_aggr.to_csv('data_aggregated.csv')

# %% [markdown]
# # Adjust cell to match changes in features!

# %%
# imputing all values for the missing months

data_aggr = data_aggr.append(pd.DataFrame({'year':2014, 'month':12, 'Ward':'Colindale North',# 'Season':'Winter', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Colindale North']['crime_count'].mean()), 
                                           'year_month':'2014-12'}, index=[dct_impute['Colindale North']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2016, 'month':10, 'Ward':'Colindale South',# 'Season':'Autumn', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Colindale South']['crime_count'].mean()), 
                                           'year_month':'2016-10'}, index=[dct_impute['Colindale South']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2021, 'month':7, 'Ward':'Edgwarebury',# 'Season':'Summer', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Edgwarebury']['crime_count'].mean()), 
                                           'year_month':'2021-7'}, index=[dct_impute['Edgwarebury']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2022, 'month':12, 'Ward':'High Barnet',# 'Season':'Winter', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='High Barnet']['crime_count'].mean()), 
                                           'year_month':'2022-12'}, index=[dct_impute['High Barnet']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2021, 'month':5, 'Ward':'Totteridge & Woodside',# 'Season':'Spring', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Totteridge & Woodside']['crime_count'].mean()), 
                                           'year_month':'2021-5'}, index=[dct_impute['Totteridge & Woodside']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2023, 'month':1, 'Ward':'Whetstone',# 'Season':'January', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Whetstone']['crime_count'].mean()), 
                                           'year_month':'2023-1'}, index=[dct_impute['Whetstone']]))

data_aggr = data_aggr.append(pd.DataFrame({'year':2020, 'month':8, 'Ward':'Woodhouse',# 'Season':'Summer', 
                               'crime_count':round(data_aggr[data_aggr['Ward']=='Woodhouse']['crime_count'].mean()), 
                                           'year_month':'2020-8'}, index=[dct_impute['Woodhouse']]))

# %%
data_aggr['timestamp']=data_aggr.index
data_aggr.sort_index(inplace=True)

# %%
print('Mean burglary count per month in Barnet:', data_aggr.crime_count.mean())
# Out:
# Mean burglary count per month in Barnet: 12.119932432432432

# %% [markdown]
# # XGBoost

# %%
def data_split_1_ward(data, ward, end_train, end_val):
    '''A single model can only handle the time series of a single ward
       This function prepares the data to train a model on a single ward
    ''' 
    
    FEATURES = ['month']
    TARGET = 'crime_count'
    
    WARD = ward
    data_1w = data[data['Ward']==WARD]
    
    train_1w = data_1w.loc[data_1w.index < end_train]
    val_1w = data_1w.loc[(data_1w.index >= end_train) & (data_1w.index < end_val)]
    test_1w = data_1w.loc[data_1w.index >= end_val]
    
    X_train_1w = train_1w[FEATURES]
    y_train_1w = train_1w[TARGET]

    X_val_1w = val_1w[FEATURES]
    y_val_1w = val_1w[TARGET]

    X_test_1w = test_1w[FEATURES]
    y_test_1w = test_1w[TARGET]
    
    return X_train_1w, X_val_1w, X_test_1w, y_train_1w, y_val_1w, y_test_1w

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=15000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=10,
                       learning_rate=0.0001)

# %%
mae = 0
rmse = 0
r2 = 0
wmape = 0

for ward in data_aggr['Ward'].unique():
    
    X_train_1w, X_val_1w, X_test_1w, y_train_1w, y_val_1w, y_test_1w = data_split_1_ward(
    data_aggr, ward, '2022-01-01', '2022-08-01')

    reg.fit(X_train_1w, y_train_1w, eval_set=[(X_val_1w, y_val_1w)], verbose=200)
    
    reg_evaluation(y_test_1w, reg.predict(X_test_1w), ward)
    
    mae += mean_absolute_error(y_test_1w, reg.predict(X_test_1w))
    rmse += mean_squared_error(y_test_1w, reg.predict(X_test_1w))
    r2 += r2_score(y_test_1w, reg.predict(X_test_1w))
    wmape += np.abs(y_test_1w - reg.predict(X_test_1w)).sum() / np.abs(y_test_1w).sum()
    
mae /= 24
rmse /= 24
rmse = np.sqrt(rmse)
r2 /= 24
wmape /= 24
# Out:
# [00:55:49] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:6.47690
# [200]	validation_0-rmse:6.26329
# [400]	validation_0-rmse:6.05553
# [600]	validation_0-rmse:5.85360
# [800]	validation_0-rmse:5.65648
# [1000]	validation_0-rmse:5.46362
# [1200]	validation_0-rmse:5.27671
# [1400]	validation_0-rmse:5.09579
# [1600]	validation_0-rmse:4.92093
# [1800]	validation_0-rmse:4.75212
# [2000]	validation_0-rmse:4.58946
# [2200]	validation_0-rmse:4.43328
# [2400]	validation_0-rmse:4.28489
# [2600]	validation_0-rmse:4.14283
# [2800]	validation_0-rmse:4.00717
# [3000]	validation_0-rmse:3.87803
# [3200]	validation_0-rmse:3.75552
# [3400]	validation_0-rmse:3.63974
# [3600]	validation_0-rmse:3.53082
# [3800]	validation_0-rmse:3.42886
# [4000]	validation_0-rmse:3.33397
# [4200]	validation_0-rmse:3.24625
# [4400]	validation_0-rmse:3.16577
# [4600]	validation_0-rmse:3.09260
# [4800]	validation_0-rmse:3.02631
# [5000]	validation_0-rmse:2.96544
# [5200]	validation_0-rmse:2.91197
# [5400]	validation_0-rmse:2.86580
# [5600]	validation_0-rmse:2.82689
# [5800]	validation_0-rmse:2.79510
# [6000]	validation_0-rmse:2.77026
# [6200]	validation_0-rmse:2.75217
# [6400]	validation_0-rmse:2.74059
# [6600]	validation_0-rmse:2.73521
# [6727]	validation_0-rmse:2.73488
# Results for Barnet Vale:
# Mean Absolute Error: 2.4
# Root Mean Squared Error: 2.82
# Weighted mean absolute percentage error: 0.49
#
#
# [00:55:58] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5.72806
# [200]	validation_0-rmse:5.54272
# [400]	validation_0-rmse:5.36196
# [600]	validation_0-rmse:5.18573
# [800]	validation_0-rmse:5.01402
# [1000]	validation_0-rmse:4.84679
# [1200]	validation_0-rmse:4.68404
# [1400]	validation_0-rmse:4.53147
# [1600]	validation_0-rmse:4.38481
# [1800]	validation_0-rmse:4.24232
# [2000]	validation_0-rmse:4.10400
# [2200]	validation_0-rmse:3.96984
# [2400]	validation_0-rmse:3.83986
# [2600]	validation_0-rmse:3.71407
# [2800]	validation_0-rmse:3.59248
# [3000]	validation_0-rmse:3.47513
# [3200]	validation_0-rmse:3.36204
# [3400]	validation_0-rmse:3.25326
# [3600]	validation_0-rmse:3.14881
# [3800]	validation_0-rmse:3.04876
# [4000]	validation_0-rmse:2.95315
# [4200]	validation_0-rmse:2.86204
# [4400]	validation_0-rmse:2.77548
# [4600]	validation_0-rmse:2.69354
# [4800]	validation_0-rmse:2.61627
# [5000]	validation_0-rmse:2.54373
# [5200]	validation_0-rmse:2.47598
# [5400]	validation_0-rmse:2.41307
# [5600]	validation_0-rmse:2.35503
# [5800]	validation_0-rmse:2.30188
# [6000]	validation_0-rmse:2.25366
# [6200]	validation_0-rmse:2.21034
# [6400]	validation_0-rmse:2.17192
# [6600]	validation_0-rmse:2.13834
# [6800]	validation_0-rmse:2.10954
# [7000]	validation_0-rmse:2.08543
# [7200]	validation_0-rmse:2.06590
# [7400]	validation_0-rmse:2.05080
# [7600]	validation_0-rmse:2.03987
# [7800]	validation_0-rmse:2.03240
# [8000]	validation_0-rmse:2.02907
# [8118]	validation_0-rmse:2.02896
# Results for Woodhouse:
# Mean Absolute Error: 2.42
# Root Mean Squared Error: 3.08
# Weighted mean absolute percentage error: 0.37
#
#
# [00:56:09] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:6.94537
# [200]	validation_0-rmse:6.77701
# [400]	validation_0-rmse:6.61235
# [600]	validation_0-rmse:6.45134
# [800]	validation_0-rmse:6.29392
# [1000]	validation_0-rmse:6.14002
# [1200]	validation_0-rmse:5.98961
# [1400]	validation_0-rmse:5.84133
# [1600]	validation_0-rmse:5.69569
# [1800]	validation_0-rmse:5.55347
# [2000]	validation_0-rmse:5.41462
# [2200]	validation_0-rmse:5.27909
# [2400]	validation_0-rmse:5.14686
# [2600]	validation_0-rmse:5.01788
# [2800]	validation_0-rmse:4.89211
# [3000]	validation_0-rmse:4.76951
# [3200]	validation_0-rmse:4.65092
# [3400]	validation_0-rmse:4.53575
# [3600]	validation_0-rmse:4.42365
# [3800]	validation_0-rmse:4.31459
# [4000]	validation_0-rmse:4.20855
# [4200]	validation_0-rmse:4.10548
# [4400]	validation_0-rmse:4.00539
# [4600]	validation_0-rmse:3.90823
# [4800]	validation_0-rmse:3.81397
# [5000]	validation_0-rmse:3.72262
# [5200]	validation_0-rmse:3.63414
# [5400]	validation_0-rmse:3.54851
# [5600]	validation_0-rmse:3.46571
# [5800]	validation_0-rmse:3.38589
# [6000]	validation_0-rmse:3.30969
# [6200]	validation_0-rmse:3.23622
# [6400]	validation_0-rmse:3.16547
# [6600]	validation_0-rmse:3.09742
# [6800]	validation_0-rmse:3.03205
# [7000]	validation_0-rmse:2.96934
# [7200]	validation_0-rmse:2.90928
# [7400]	validation_0-rmse:2.85184
# [7600]	validation_0-rmse:2.79945
# [7800]	validation_0-rmse:2.75303
# [8000]	validation_0-rmse:2.70922
# [8200]	validation_0-rmse:2.66798
# [8400]	validation_0-rmse:2.62929
# [8600]	validation_0-rmse:2.59310
# [8800]	validation_0-rmse:2.55936
# [9000]	validation_0-rmse:2.52805
# [9200]	validation_0-rmse:2.50209
# [9400]	validation_0-rmse:2.47891
# [9600]	validation_0-rmse:2.45792
# [9800]	validation_0-rmse:2.43908
# [10000]	validation_0-rmse:2.42231
# [10200]	validation_0-rmse:2.40755
# [10400]	validation_0-rmse:2.39473
# [10600]	validation_0-rmse:2.38378
# [10800]	validation_0-rmse:2.37462
# [11000]	validation_0-rmse:2.36718
# [11200]	validation_0-rmse:2.36139
# [11400]	validation_0-rmse:2.35716
# [11600]	validation_0-rmse:2.35442
# [11800]	validation_0-rmse:2.35309
# [11943]	validation_0-rmse:2.35297
# Results for Whetstone:
# Mean Absolute Error: 2.46
# Root Mean Squared Error: 2.8
# Weighted mean absolute percentage error: 0.35
#
#
# [00:56:24] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.70523
# [200]	validation_0-rmse:7.41885
# [400]	validation_0-rmse:7.13875
# [600]	validation_0-rmse:6.86486
# [800]	validation_0-rmse:6.59711
# [1000]	validation_0-rmse:6.33544
# [1200]	validation_0-rmse:6.07980
# [1400]	validation_0-rmse:5.83015
# [1600]	validation_0-rmse:5.58647
# [1800]	validation_0-rmse:5.34872
# [2000]	validation_0-rmse:5.11691
# [2200]	validation_0-rmse:4.89104
# [2400]	validation_0-rmse:4.67114
# [2600]	validation_0-rmse:4.45723
# [2800]	validation_0-rmse:4.24939
# [3000]	validation_0-rmse:4.04770
# [3200]	validation_0-rmse:3.85226
# [3400]	validation_0-rmse:3.66322
# [3600]	validation_0-rmse:3.48075
# [3800]	validation_0-rmse:3.30507
# [4000]	validation_0-rmse:3.13644
# [4200]	validation_0-rmse:2.97517
# [4400]	validation_0-rmse:2.82161
# [4600]	validation_0-rmse:2.67620
# [4800]	validation_0-rmse:2.53942
# [5000]	validation_0-rmse:2.41183
# [5200]	validation_0-rmse:2.29402
# [5400]	validation_0-rmse:2.18666
# [5600]	validation_0-rmse:2.09044
# [5800]	validation_0-rmse:2.00602
# [6000]	validation_0-rmse:1.93405
# [6200]	validation_0-rmse:1.87506
# [6400]	validation_0-rmse:1.82940
# [6600]	validation_0-rmse:1.79795
# [6800]	validation_0-rmse:1.77988
# [7000]	validation_0-rmse:1.77448
# [7038]	validation_0-rmse:1.77484
# Results for West Hendon:
# Mean Absolute Error: 2.24
# Root Mean Squared Error: 2.66
# Weighted mean absolute percentage error: 0.22
#
#
# [00:56:33] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:8.97271
# [200]	validation_0-rmse:8.68536
# [400]	validation_0-rmse:8.40517
# [600]	validation_0-rmse:8.13209
# [800]	validation_0-rmse:7.86609
# [1000]	validation_0-rmse:7.60713
# [1200]	validation_0-rmse:7.35519
# [1400]	validation_0-rmse:7.11025
# [1600]	validation_0-rmse:6.86293
# [1800]	validation_0-rmse:6.62124
# [2000]	validation_0-rmse:6.38548
# [2200]	validation_0-rmse:6.15561
# [2400]	validation_0-rmse:5.93162
# [2600]	validation_0-rmse:5.71351
# [2800]	validation_0-rmse:5.50127
# [3000]	validation_0-rmse:5.29492
# [3200]	validation_0-rmse:5.09449
# [3400]	validation_0-rmse:4.90002
# [3600]	validation_0-rmse:4.71155
# [3800]	validation_0-rmse:4.52916
# [4000]	validation_0-rmse:4.35293
# [4200]	validation_0-rmse:4.18296
# [4400]	validation_0-rmse:4.01936
# [4600]	validation_0-rmse:3.86228
# [4800]	validation_0-rmse:3.71186
# [5000]	validation_0-rmse:3.56827
# [5200]	validation_0-rmse:3.43172
# [5400]	validation_0-rmse:3.30241
# [5600]	validation_0-rmse:3.18056
# [5800]	validation_0-rmse:3.06640
# [6000]	validation_0-rmse:2.96018
# [6200]	validation_0-rmse:2.86214
# [6400]	validation_0-rmse:2.77280
# [6600]	validation_0-rmse:2.69262
# [6800]	validation_0-rmse:2.62150
# [7000]	validation_0-rmse:2.55958
# [7200]	validation_0-rmse:2.50694
# [7400]	validation_0-rmse:2.46360
# [7600]	validation_0-rmse:2.42948
# [7800]	validation_0-rmse:2.40442
# [8000]	validation_0-rmse:2.38818
# [8200]	validation_0-rmse:2.38044
# [8341]	validation_0-rmse:2.37987
# Results for West Finchley:
# Mean Absolute Error: 3.73
# Root Mean Squared Error: 4.27
# Weighted mean absolute percentage error: 0.32
#
#
# [00:56:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:2.92099
# [200]	validation_0-rmse:2.80301
# [400]	validation_0-rmse:2.69137
# [600]	validation_0-rmse:2.58627
# [800]	validation_0-rmse:2.49489
# [1000]	validation_0-rmse:2.42121
# [1200]	validation_0-rmse:2.35509
# [1400]	validation_0-rmse:2.29665
# [1600]	validation_0-rmse:2.24600
# [1800]	validation_0-rmse:2.20315
# [2000]	validation_0-rmse:2.16809
# [2200]	validation_0-rmse:2.14074
# [2400]	validation_0-rmse:2.12094
# [2600]	validation_0-rmse:2.10564
# [2800]	validation_0-rmse:2.09512
# [3000]	validation_0-rmse:2.09009
# [3097]	validation_0-rmse:2.09004
# Results for Underhill:
# Mean Absolute Error: 0.94
# Root Mean Squared Error: 1.16
# Weighted mean absolute percentage error: 0.36
#
#
# [00:56:48] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:6.96602
# [200]	validation_0-rmse:6.82078
# [400]	validation_0-rmse:6.67932
# [600]	validation_0-rmse:6.54160
# [800]	validation_0-rmse:6.40755
# [1000]	validation_0-rmse:6.27762
# [1200]	validation_0-rmse:6.15148
# [1400]	validation_0-rmse:6.02877
# [1600]	validation_0-rmse:5.90948
# [1800]	validation_0-rmse:5.79354
# [2000]	validation_0-rmse:5.68092
# [2200]	validation_0-rmse:5.57157
# [2400]	validation_0-rmse:5.46546
# [2600]	validation_0-rmse:5.36254
# [2800]	validation_0-rmse:5.26279
# [3000]	validation_0-rmse:5.16614
# [3200]	validation_0-rmse:5.07257
# [3400]	validation_0-rmse:4.98203
# [3600]	validation_0-rmse:4.89450
# [3800]	validation_0-rmse:4.80991
# [4000]	validation_0-rmse:4.72825
# [4200]	validation_0-rmse:4.64947
# [4400]	validation_0-rmse:4.57352
# [4600]	validation_0-rmse:4.50038
# [4800]	validation_0-rmse:4.42999
# [5000]	validation_0-rmse:4.36232
# [5200]	validation_0-rmse:4.29732
# [5400]	validation_0-rmse:4.23495
# [5600]	validation_0-rmse:4.17518
# [5800]	validation_0-rmse:4.11794
# [6000]	validation_0-rmse:4.06321
# [6200]	validation_0-rmse:4.01093
# [6400]	validation_0-rmse:3.96106
# [6600]	validation_0-rmse:3.91354
# [6800]	validation_0-rmse:3.86834
# [7000]	validation_0-rmse:3.82540
# [7200]	validation_0-rmse:3.78467
# [7400]	validation_0-rmse:3.74609
# [7600]	validation_0-rmse:3.70963
# [7800]	validation_0-rmse:3.67521
# [8000]	validation_0-rmse:3.64280
# [8200]	validation_0-rmse:3.61233
# [8400]	validation_0-rmse:3.58375
# [8600]	validation_0-rmse:3.55701
# [8800]	validation_0-rmse:3.53204
# [2600]	validation_0-rmse:6.58575
# [2800]	validation_0-rmse:6.41068
# [3000]	validation_0-rmse:6.24130
# [3200]	validation_0-rmse:6.07761
# [3400]	validation_0-rmse:5.91959
# [3600]	validation_0-rmse:5.76694
# [3800]	validation_0-rmse:5.61991
# [4000]	validation_0-rmse:5.47855
# [4200]	validation_0-rmse:5.34288
# [4400]	validation_0-rmse:5.21287
# [4600]	validation_0-rmse:5.08854
# [4800]	validation_0-rmse:4.96988
# [5000]	validation_0-rmse:4.85688
# [5200]	validation_0-rmse:4.74954
# [5400]	validation_0-rmse:4.64785
# [5600]	validation_0-rmse:4.55180
# [5800]	validation_0-rmse:4.46136
# [6000]	validation_0-rmse:4.37650
# [6200]	validation_0-rmse:4.29719
# [6400]	validation_0-rmse:4.22339
# [6600]	validation_0-rmse:4.15504
# [6800]	validation_0-rmse:4.09207
# [7000]	validation_0-rmse:4.03441
# [7200]	validation_0-rmse:3.98198
# [7400]	validation_0-rmse:3.93466
# [7600]	validation_0-rmse:3.89235
# [7800]	validation_0-rmse:3.85494
# [8000]	validation_0-rmse:3.82260
# [8200]	validation_0-rmse:3.79612
# [8400]	validation_0-rmse:3.77398
# [8600]	validation_0-rmse:3.75603
# [8800]	validation_0-rmse:3.74210
# [9000]	validation_0-rmse:3.73199
# [9200]	validation_0-rmse:3.72558
# [9400]	validation_0-rmse:3.72269
# [9529]	validation_0-rmse:3.72260
# Results for Golders Green:
# Mean Absolute Error: 2.59
# Root Mean Squared Error: 2.8
# Weighted mean absolute percentage error: 0.29
#
#
# [00:57:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:5.42055
# [200]	validation_0-rmse:5.22884
# [400]	validation_0-rmse:5.04196
# [600]	validation_0-rmse:4.86047
# [800]	validation_0-rmse:4.68563
# [1000]	validation_0-rmse:4.51529
# [1200]	validation_0-rmse:4.34942
# [1400]	validation_0-rmse:4.18802
# [1600]	validation_0-rmse:4.03113
# [1800]	validation_0-rmse:3.87875
# [2000]	validation_0-rmse:3.73092
# [2200]	validation_0-rmse:3.58770
# [2400]	validation_0-rmse:3.44912
# [2600]	validation_0-rmse:3.31528
# [2800]	validation_0-rmse:3.18625
# [3000]	validation_0-rmse:3.06212
# [3200]	validation_0-rmse:2.94301
# [3400]	validation_0-rmse:2.82905
# [3600]	validation_0-rmse:2.72036
# [3800]	validation_0-rmse:2.61711
# [4000]	validation_0-rmse:2.51946
# [4200]	validation_0-rmse:2.42758
# [4400]	validation_0-rmse:2.34166
# [4600]	validation_0-rmse:2.26189
# [4800]	validation_0-rmse:2.18846
# [5000]	validation_0-rmse:2.12154
# [5200]	validation_0-rmse:2.06066
# [5400]	validation_0-rmse:2.00432
# [5600]	validation_0-rmse:1.95467
# [5800]	validation_0-rmse:1.91180
# [6000]	validation_0-rmse:1.87574
# [6200]	validation_0-rmse:1.84643
# [6400]	validation_0-rmse:1.82383
# [6600]	validation_0-rmse:1.80780
# [6800]	validation_0-rmse:1.79551
# [7000]	validation_0-rmse:1.78925
# [7157]	validation_0-rmse:1.78842
# Results for Garden Suburb:
# Mean Absolute Error: 1.69
# Root Mean Squared Error: 2.14
# Weighted mean absolute percentage error: 0.26
#
#
# [00:57:54] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:
# [9800]	validation_0-rmse:6.10802
# [10000]	validation_0-rmse:6.04108
# [10200]	validation_0-rmse:5.97835
# [10400]	validation_0-rmse:5.91961
# [10600]	validation_0-rmse:5.86477
# [10800]	validation_0-rmse:5.81363
# [11000]	validation_0-rmse:5.76627
# [11200]	validation_0-rmse:5.72265
# [11400]	validation_0-rmse:5.68266
# [11600]	validation_0-rmse:5.64607
# [11800]	validation_0-rmse:5.61269
# [12000]	validation_0-rmse:5.58254
# [12200]	validation_0-rmse:5.55537
# [12400]	validation_0-rmse:5.53119
# [12600]	validation_0-rmse:5.50975
# [12800]	validation_0-rmse:5.49110
# [13000]	validation_0-rmse:5.47494
# [13200]	validation_0-rmse:5.46132
# [13400]	validation_0-rmse:5.44998
# [13600]	validation_0-rmse:5.44095
# [13800]	validation_0-rmse:5.43397
# [14000]	validation_0-rmse:5.42908
# [14200]	validation_0-rmse:5.42605
# [14400]	validation_0-rmse:5.42490
# [14498]	validation_0-rmse:5.42488
# Results for Childs Hill:
# Mean Absolute Error: 6.75
# Root Mean Squared Error: 8.15
# Weighted mean absolute percentage error: 0.3
#
#
# [01:00:36] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:14.24012
# [200]	validation_0-rmse:13.96054
# [400]	validation_0-rmse:13.68783
# [600]	validation_0-rmse:13.42187
# [800]	validation_0-rmse:13.16256
# [1000]	validation_0-rmse:12.90980
# [1200]	validation_0-rmse:12.66348
# [1400]	validation_0-rmse:12.42350
# [1600]	validation_0-rmse:12.18977
# [1800]	validation_0-rmse:11.96219
# [2000]	validation_0-rmse:11.74067
# [2200]	validation_0-rmse:11.52511
# [2400]	validation_0-rmse:11.31542
# [2600]	validation_0-rmse:11.11152
# [2800]	validation_0-rmse:10.91330
# [3000]	validation_0-rmse:10.72373
# [3200]	validation_0-rmse:10.54905
# [3400]	validation_0-rmse:10.37440
# [3600]	validation_0-rmse:10.20421
# [3800]	validation_0-rmse:10.03940
# [4000]	validation_0-rmse:9.87989
# [4200]	validation_0-rmse:9.72560
# [4400]	validation_0-rmse:9.57650
# [4600]	validation_0-rmse:9.43239
# [4800]	validation_0-rmse:9.29330
# [5000]	validation_0-rmse:9.15908
# [5200]	validation_0-rmse:9.02966
# [5400]	validation_0-rmse:8.90494
# [5600]	validation_0-rmse:8.78490
# [5800]	validation_0-rmse:8.67397
# [6000]	validation_0-rmse:8.56797
# [6200]	validation_0-rmse:8.46617
# [6400]	validation_0-rmse:8.36829
# [6600]	validation_0-rmse:8.27446
# [6800]	validation_0-rmse:8.18445
# [7000]	validation_0-rmse:8.09833
# [7200]	validation_0-rmse:8.01591
# [7400]	validation_0-rmse:7.93710
# [7600]	validation_0-rmse:7.86182
# [7800]	validation_0-rmse:7.79011
# [8000]	validation_0-rmse:7.72173
# [8200]	validation_0-rmse:7.65662
# [8400]	validation_0-rmse:7.59472
# [8600]	validation_0-rmse:7.53588
# [8800]	validation_0-rmse:7.48089
# [9000]	validation_0-rmse:7.42946
# [9200]	validation_0-rmse:7.38091
# [9400]	validation_0-rmse:7.33505
# [9600]	validation_0-rmse:7.29181
# [9800]	validation_0-rmse:7.25122
# [10000]	validation_0-rmse:7.21300
# [10200]	validation_0-rmse:7.17725
# [10400]	validation_0-rmse:7.14374
# [10600]	validation_0-rmse:7.11243
# [10800]	validation_0-rmse:7.08326
# [11000]	validation_0-rmse:7.05622
# [11200]	validation_0-rmse:7.03106
# [11400]	validation_0-rmse:7.00782
# [11600]	validation_0-rmse:6.98644
# [11800]	validation_0-rmse:6.96676
# [12000]	validation_0-rmse:6.94874
# [12200]	validation_0-rmse:6.93237
# [12400]	validation_0-rmse:6.91741
# [12600]	validation_0-rmse:6.90403
# [12800]	validation_0-rmse:6.89197
# [13000]	validation_0-rmse:6.88125
# [13122]	validation_0-rmse:6.87802
# Results for Burnt Oak:
# Mean Absolute Error: 2.04
# Root Mean Squared Error: 3.16
# Weighted mean absolute percentage error: 0.18
#
#
# [01:00:57] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:6.56451
# [200]	validation_0-rmse:6.34734
# [400]	validation_0-rmse:6.13498
# [600]	validation_0-rmse:5.92736
# [800]	validation_0-rmse:5.72443
# [1000]	validation_0-rmse:5.52615
# [1200]	validation_0-rmse:5.33248
# [1400]	validation_0-rmse:5.14338
# [1600]	validation_0-rmse:4.95883
# [1800]	validation_0-rmse:4.77880
# [2000]	validation_0-rmse:4.60328
# [2200]	validation_0-rmse:4.43226
# [2400]	validation_0-rmse:4.26573
# [2600]	validation_0-rmse:4.10370
# [2800]	validation_0-rmse:3.94619
# [3000]	validation_0-rmse:3.79322
# [3200]	validation_0-rmse:3.64484
# [3400]	validation_0-rmse:3.50108
# [3600]	validation_0-rmse:3.36201
# [3800]	validation_0-rmse:3.22770
# [4000]	validation_0-rmse:3.09824
# [4200]	validation_0-rmse:2.97373
# [4400]	validation_0-rmse:2.85429
# [4600]	validation_0-rmse:2.74006
# [4800]	validation_0-rmse:2.63119
# [5000]	validation_0-rmse:2.52784
# [5200]	validation_0-rmse:2.43019
# [5400]	validation_0-rmse:2.33845
# [5600]	validation_0-rmse:2.25281
# [5800]	validation_0-rmse:2.17349
# [6000]	validation_0-rmse:2.10069
# [6200]	validation_0-rmse:2.03310
# [6400]	validation_0-rmse:1.97170
# [6600]	validation_0-rmse:1.91747
# [6800]	validation_0-rmse:1.87055
# [7000]	validation_0-rmse:1.83103
# [7200]	validation_0-rmse:1.79893
# [7400]	validation_0-rmse:1.77421
# [7600]	validation_0-rmse:1.75674
# [7800]	validation_0-rmse:1.74631
# [7975]	validation_0-rmse:1.74443
# Results for Brunswick Park:
# Mean Absolute Error: 2.84
# Root Mean Squared Error: 3.47
# Weighted mean absolute percentage error: 0.34
#
#
# [01:01:08] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:10.71398
# [200]	validation_0-rmse:10.41783
# [400]	validation_0-rmse:10.12811
# [600]	validation_0-rmse:9.84472
# [800]	validation_0-rmse:9.56758
# [1000]	validation_0-rmse:9.29657
# [1200]	validation_0-rmse:9.03163
# [1400]	validation_0-rmse:8.77200
# [1600]	validation_0-rmse:8.50669
# [1800]	validation_0-rmse:8.24702
# [2000]	validation_0-rmse:7.99291
# [2200]	validation_0-rmse:7.74427
# [2400]	validation_0-rmse:7.50103
# [2600]	validation_0-rmse:7.26312
# [2800]	validation_0-rmse:7.03047
# [3000]	validation_0-rmse:6.80302
# [3200]	validation_0-rmse:6.58072
# [3400]	validation_0-rmse:6.36350
# [3600]	validation_0-rmse:6.15372
# [3800]	validation_0-rmse:5.94899
# [4000]	validation_0-rmse:5.74909
# [4200]	validation_0-rmse:5.55698
# [4400]	validation_0-rmse:5.37082
# [4600]	validation_0-rmse:5.18920
# [4800]	validation_0-rmse:5.01209
# [5000]	validation_0-rmse:4.83947
# [5200]	validation_0-rmse:4.67133
# [5400]	validation_0-rmse:4.50767
# [5600]	validation_0-rmse:4.34848
# [5800]	validation_0-rmse:4.19377
# [6000]	validation_0-rmse:4.04273
# [6200]	validation_0-rmse:3.89627
# [6400]	validation_0-rmse:3.75467
# [6600]	validation_0-rmse:3.61792
# [6800]	validation_0-rmse:3.48608
# [7000]	validation_0-rmse:3.35920
# [7200]	validation_0-rmse:3.23739
# [7400]	validation_0-rmse:3.12143
# [7600]	validation_0-rmse:3.01232
# [7800]	validation_0-rmse:2.90824
# [8000]	validation_0-rmse:2.80923
# [8200]	validation_0-rmse:2.71545
# [8400]	validation_0-rmse:2.62698
# [8600]	validation_0-rmse:2.54398
# [8800]	validation_0-rmse:2.46649
# [9000]	validation_0-rmse:2.39470
# [9200]	validation_0-rmse:2.32867
# [9400]	validation_0-rmse:2.26763
# [9600]	validation_0-rmse:2.21110
# [9800]	validation_0-rmse:2.16061
# [10000]	validation_0-rmse:2.11620
# [10200]	validation_0-rmse:2.07787
# [10400]	validation_0-rmse:2.04560
# [10600]	validation_0-rmse:2.01932
# [10800]	validation_0-rmse:1.99891
# [11000]	validation_0-rmse:1.98423
# [11200]	validation_0-rmse:1.97510
# [11400]	validation_0-rmse:1.97125
# [11501]	validation_0-rmse:1.97124
# Results for Finchley Church End:
# Mean Absolute Error: 3.64
# Root Mean Squared Error: 4.03
# Weighted mean absolute percentage error: 0.29

# %%
print('Metrics for XGB w/o MLForecast')
print('MAE:', mae)
print('RMSE:', rmse)
print('WMAPE:', wmape)
# print('R2:', r2)
# Out:
# Metrics for XGB w/o MLForecast
# MAE: 3.0697665909926095
# RMSE: 3.941328990432361
# WMAPE: 0.3480948173694325

# %% [markdown]
# ### Split data for DeepAR and XGB w/ MLForecast

# %%
train = data_aggr.loc[(data_aggr.index >= '2010-03-01') & (data_aggr.index < '2022-03-01')]
train2 = data_aggr.loc[(data_aggr.index >= '2020-03-01') & (data_aggr.index < '2022-03-01')]
val = data_aggr.loc[data_aggr.index >= '2022-03-01']

# %% [markdown]
# ## XGB with MLForecast (unfinished)

# %%
dct_idx = dict(zip(list(val['year_month'].unique()), [i for i in range(1, len(val['year_month'].unique())+1)]))
val_MLF = val.replace({"year_month": dct_idx})

# %%
from mlforecast import MLForecast

from window_ops.rolling import rolling_mean, rolling_max, rolling_min


reg2 = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=10000,
                       objective='reg:linear',
                       max_depth=10,
                       learning_rate=0.0001)

model = MLForecast(models=reg2,
                   freq='M',
                   lags=[1, 12],
                   lag_transforms={
                       1: [(rolling_mean, 3), (rolling_max, 3), (rolling_min, 3)],},
                   num_threads=4)


model.fit(train2[['month','crime_count','Ward']], id_col='Ward', time_col='month', target_col='crime_count', 
        static_features=[])
# Out:
# C:\Users\Goshko\anaconda3\lib\site-packages\mlforecast\core.py:218: UserWarning: Setting `freq=1` since time col is int.
#   warnings.warn("Setting `freq=1` since time col is int.")
# [01:27:45] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# MLForecast(models=[XGBRegressor], freq=1, lag_features=['lag1', 'lag12', 'rolling_mean_lag1_window_size3', 'rolling_max_lag1_window_size3', 'rolling_min_lag1_window_size3'], date_features=[], num_threads=4)

# %%
# collecting predictions 

p = model.predict(horizon=val_MLF['timestamp'].nunique())
p['year_month'] = p['month']
p.drop(columns=['month'], inplace=True)
p['year_month'] = p['year_month']-12
p = p.merge(val_MLF[['Ward', 'timestamp', 'year_month', 'crime_count']], on=['Ward', 'year_month'], how='left')

# %%
p[['Ward', 'XGBRegressor', 'crime_count', 'timestamp']].loc[52:64]
# Out:
#                Ward  XGBRegressor  crime_count  timestamp
# 52  Colindale North      3.661759            6 2022-03-01
# 53  Colindale North      3.150340            4 2022-04-01
# 54  Colindale North      4.290215            4 2022-05-01
# 55  Colindale North      4.228911            3 2022-06-01
# 56  Colindale North      6.698258            8 2022-07-01
# 57  Colindale North      4.092427            4 2022-08-01
# 58  Colindale North      6.528521            6 2022-09-01
# 59  Colindale North      3.343265            4 2022-10-01
# 60  Colindale North      4.214192            5 2022-11-01
# 61  Colindale North      4.788652            6 2022-12-01
# 62  Colindale North      5.797309            5 2023-01-01
# 63  Colindale North      3.226776            3 2023-02-01
# 64  Colindale North      5.550349            7 2023-03-01

# %% [markdown]
# # DeepAR

# %%
def wmape(y_true, y_pred):
    '''Weighted Mean Absolute Percentage Error
    '''
    
    return np.abs(y_true - y_pred).sum() / np.abs(y_true).sum()

# %%
from gluonts.dataset.pandas import PandasDataset

train_ds = PandasDataset.from_long_dataframe(train, target='crime_count', item_id='Ward', 
                                       timestamp='year_month', freq='M')

# %%
from gluonts.torch.model.deepar import DeepAREstimator

estimator = DeepAREstimator(freq='M', prediction_length=6, num_layers=3, lr=0.0005, context_length=24,
                            trainer_kwargs={'max_epochs':6})

predictor = estimator.train(train_ds, num_workers=4)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\Goshko\anaconda3\lib\site-packages\pytorch_lightning\trainer\configuration_validator.py:110: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   category=PossibleUserWarning,
#
#   | Name  | Type        | Params | In sizes | Out sizes
# ---------------------------------------------------------------
# 0 | model | DeepARModel | 36.4 K | ?        | [1, 100, 6]
# ---------------------------------------------------------------
# 36.4 K    Trainable params
# 0         Non-trainable params
# 36.4 K    Total params
# 0.146     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 3.34050 (best 3.34050), saving model to 'C:\\Users\\Goshko\\Desktop\\DC 2\\JBG050-Group-3\\lightning_logs\\version_73\\checkpoints\\epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 2.85648 (best 2.85648), saving model to 'C:\\Users\\Goshko\\Desktop\\DC 2\\JBG050-Group-3\\lightning_logs\\version_73\\checkpoints\\epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 2.80591 (best 2.80591), saving model to 'C:\\Users\\Goshko\\Desktop\\DC 2\\JBG050-Group-3\\lightning_logs\\version_73\\checkpoints\\epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' was not in top 1
# Epoch 4, global step 250: 'train_loss' reached 2.77094 (best 2.77094), saving model to 'C:\\Users\\Goshko\\Desktop\\DC 2\\JBG050-Group-3\\lightning_logs\\version_73\\checkpoints\\epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 2.74367 (best 2.74367), saving model to 'C:\\Users\\Goshko\\Desktop\\DC 2\\JBG050-Group-3\\lightning_logs\\version_73\\checkpoints\\epoch=5-step=300.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=6` reached.

# %%
# collect predictions

pred = list(predictor.predict(train_ds))
all_preds = list()
for ward in pred:
    ward_name = ward.item_id
    p = ward.samples.mean(axis=0)
    p10 = np.percentile(ward.samples, 10, axis=0)
    # making an 80% confidence interval
    p90 = np.percentile(ward.samples, 90, axis=0)
    dates = pd.date_range(start=ward.start_date.to_timestamp(), periods=len(p), freq='M')
    ward_pred = pd.DataFrame({'timestamp-1': dates, 'Ward': ward_name, 'pred': p, 'p10': p10, 'p90': p90})
    ward_pred['timestamp']  = ward_pred['timestamp-1'] + timedelta(days=1)
    all_preds += [ward_pred]

all_preds = pd.concat(all_preds, ignore_index=True)
all_preds = all_preds.merge(val, on=['timestamp', 'Ward'], how='left')

# %%
wmape(all_preds['crime_count'], all_preds['pred'])
# Out:
# 0.30915030985013814

# %%
reg_evaluation(all_preds['crime_count'], all_preds['pred'], 'all wards')
# Out:
# Results for all wards:
# Mean Absolute Error: 2.42
# Root Mean Squared Error: 3.26
# Weighted mean absolute percentage error: 0.31

# %%
fig, ax = plt.subplots(12,2, figsize=(2*1280/96, 4*1280/96), dpi=96)
ax = ax.flatten()

for ax_ ,ward in enumerate(all_preds['Ward'].unique()):
    p_ = all_preds.loc[all_preds['Ward'] == ward]
    p_.plot(x='timestamp', y='crime_count', ax=ax[ax_], label='Crime count')
    p_.plot(x='timestamp', y='pred', ax=ax[ax_], label='Forecast')
    ax[ax_].fill_between(p_['timestamp'].values, p_['p10'], p_['p90'], alpha=0.2, color='orange')
    ax[ax_].set_title(ward)
    ax[ax_].legend()
    ax[ax_].set_xlabel('Date')
    ax[ax_].set_ylabel('Crime count')
    
fig.tight_layout()
