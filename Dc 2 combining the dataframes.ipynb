# %%
import pandas as pd
import csv

# %%
# spreadsheet = pd.read_csv('2023-02/2020-06/2020-06-city-of-london-street.csv')
df_2020_03 = pd.read_csv('2023-02/2020-03/2020-03-metropolitan-street.csv')
df_2020_04 = pd.read_csv('2023-02/2020-04/2020-04-metropolitan-street.csv')
df_2020_05 = pd.read_csv('2023-02/2020-05/2020-05-metropolitan-street.csv')
df_2020_06 = pd.read_csv('2023-02/2020-06/2020-06-metropolitan-street.csv')
df_2020_07 = pd.read_csv('2023-02/2020-07/2020-07-metropolitan-street.csv')
df_2020_08 = pd.read_csv('2023-02/2020-08/2020-08-metropolitan-street.csv')
df_2020_09 = pd.read_csv('2023-02/2020-09/2020-09-metropolitan-street.csv')
df_2020_10 = pd.read_csv('2023-02/2020-10/2020-10-metropolitan-street.csv')
df_2020_11 = pd.read_csv('2023-02/2020-11/2020-11-metropolitan-street.csv')
df_2020_12 = pd.read_csv('2023-02/2020-12/2020-12-metropolitan-street.csv')
df_2021_01 = pd.read_csv('2023-02/2021-01/2021-01-metropolitan-street.csv')
df_2021_02 = pd.read_csv('2023-02/2021-02/2021-02-metropolitan-street.csv')
df_2021_03 = pd.read_csv('2023-02/2021-03/2021-03-metropolitan-street.csv')
df_2021_04 = pd.read_csv('2023-02/2021-04/2021-04-metropolitan-street.csv')
df_2021_05 = pd.read_csv('2023-02/2021-05/2021-05-metropolitan-street.csv')
df_2021_06 = pd.read_csv('2023-02/2021-06/2021-06-metropolitan-street.csv')
df_2021_07 = pd.read_csv('2023-02/2021-07/2021-07-metropolitan-street.csv')
df_2021_08 = pd.read_csv('2023-02/2021-08/2021-08-metropolitan-street.csv')
df_2021_09 = pd.read_csv('2023-02/2021-09/2021-09-metropolitan-street.csv')
df_2021_10 = pd.read_csv('2023-02/2021-10/2021-10-metropolitan-street.csv')
df_2021_11 = pd.read_csv('2023-02/2021-11/2021-11-metropolitan-street.csv')
df_2021_12 = pd.read_csv('2023-02/2021-12/2021-12-metropolitan-street.csv')
df_2022_01 = pd.read_csv('2023-02/2022-01/2022-01-metropolitan-street.csv')
df_2022_02 = pd.read_csv('2023-02/2022-02/2022-02-metropolitan-street.csv')
df_2022_03 = pd.read_csv('2023-02/2022-03/2022-03-metropolitan-street.csv')
df_2022_04 = pd.read_csv('2023-02/2022-04/2022-04-metropolitan-street.csv')
df_2022_05 = pd.read_csv('2023-02/2022-05/2022-05-metropolitan-street.csv')
df_2022_06 = pd.read_csv('2023-02/2022-06/2022-06-metropolitan-street.csv')
df_2022_07 = pd.read_csv('2023-02/2022-07/2022-07-metropolitan-street.csv')
df_2022_08 = pd.read_csv('2023-02/2022-08/2022-08-metropolitan-street.csv')
df_2022_09 = pd.read_csv('2023-02/2022-09/2022-09-metropolitan-street.csv')
df_2022_10 = pd.read_csv('2023-02/2022-10/2022-10-metropolitan-street.csv')
df_2022_11 = pd.read_csv('2023-02/2022-11/2022-11-metropolitan-street.csv')
df_2022_12 = pd.read_csv('2023-02/2022-12/2022-12-metropolitan-street.csv')
df_2023_01 = pd.read_csv('2023-02/2023-01/2023-01-metropolitan-street.csv')
df_2023_02 = pd.read_csv('2023-02/2023-02/2023-02-metropolitan-street.csv')



# test = spreadsheet.copy()
# test_append = [df_2020_03,df_2020_04]
appending_2020 = [df_2020_04, df_2020_05, df_2020_06, df_2020_07, df_2020_08, df_2020_09, df_2020_10, df_2020_11, df_2020_12]
appending_2021 = [df_2021_02, df_2021_03, df_2021_04, df_2021_05, df_2021_06, df_2021_07, df_2021_08, df_2021_09, df_2021_10, df_2021_11, df_2021_12]
appending_2022 = [df_2022_02, df_2022_03, df_2022_04, df_2022_05, df_2021_06, df_2022_07, df_2022_08, df_2022_09, df_2022_10, df_2022_11, df_2022_12]

# %%
# test.shape #323
df_2020_03.shape #605
df_2020_04.shape #236
# Out:
# (109951, 12)

# %%
#test.drop(test[test['Crime type'] != 'Burglary'].index, inplace=True)

# df_merge = test.append(test_append, ignore_index=True)

df_merge_2020 = df_2020_03.append(appending_2020, ignore_index=True)
df_merge_2021 = df_2021_01.append(appending_2021, ignore_index=True)
df_merge_2022 = df_2022_01.append(appending_2022, ignore_index=True)
df_merge_2023 = df_2023_01.append(df_2023_02, ignore_index=True)

df_merge_total = df_merge_2020.append([df_merge_2021, df_merge_2022, df_merge_2023], ignore_index = True)
# df_merge_total.head()
df = df_merge_total.copy()
df.drop(df[df['Crime type'] != 'Burglary'].index, inplace=True)
df = df.reset_index(drop = True)
df

# df.to_csv('combining_df.csv')
# test
# the different crimes
# test['Crime type'].unique()
# Out:
# C:\Users\20213338\AppData\Local\Temp\ipykernel_18300\3058137570.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merge_2020 = df_2020_03.append(appending_2020, ignore_index=True)
# C:\Users\20213338\AppData\Local\Temp\ipykernel_18300\3058137570.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merge_2021 = df_2021_01.append(appending_2021, ignore_index=True)
# C:\Users\20213338\AppData\Local\Temp\ipykernel_18300\3058137570.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merge_2022 = df_2022_01.append(appending_2022, ignore_index=True)
# ...

# %%
df
# Out:
#                                                  Crime ID    Month  \
# 0       3f69f7d8f8a3b261221b1509172d72c8c08f6fb475055b...  2020-03
# 1       305415befc01a2a0d966e0a5d58670316ef3e57412d7cb...  2020-03
# 2       9879e99454b863ae0f9cbdf33a4af544c32ca6051c112b...  2020-03
# 3       e24bcf76cedb45f0f7cb73f69850aef3eddeb6630881ba...  2020-03
# 4       804627857b8b089b6b817e8a8acce0000ce3998cbf18d4...  2020-03
# ...                                                   ...      ...
# 164661  e112b5103ee16e78f4230cf31b055f6a254f1a0cdb3334...  2023-02
# 164662  eccb4172f8b1535de3c2727b45cff6e1dd32e7035b53b1...  2023-02
# 164663  ae7d35f15ec48836a7d80859b87dfab505ce088b64d905...  2023-02
# 164664  60cec9bb59258d9df5d9f337ad6aa08c80bfb3b2b366b1...  2023-02
# 164665  0ac883fe28484bcf9834ec8e415cec848bb823bb490294...  2023-02
#
#                         Reported by                 Falls within  Longitude  \
# 0       Metropolitan Police Service  Metropolitan Police Service   0.140035
# ...

# %%
# drop missing rows when it has a null value in the LSOA column or LSAOA name 
df.dropna(subset = ['LSOA name','LSOA code'], inplace=True)

# %%
# if the LSOA name contains Barnet keep the rows. 
df_barnet = df.loc[df['LSOA name'].str.contains("Barnet", case=False)]
df_barnet
a = df_barnet["LSOA code"].unique()
b = (list(a))
len(b)
# Out:
# 211

# %%
import pandas as pd
# test = 'LSOA_differences.csv'

lsoa = pd.read_csv('LSOA_(2011)_to_LSOA_(2021).csv')

# filter the data to include only the LSOA codes in Barnet 
barnet_lsoas = lsoa[lsoa['LAD22NM'] == 'Barnet']

lsoa_barnet = list(barnet_lsoas['LSOA21CD'].unique())
len(lsoa_barnet)
# type(lsoa_barnet)
# Out:
# 220

# %%
lst_diff = []
for element in lsoa_barnet:
    if element in b:
        lst_diff.append(element)
        
len(lst_diff)
# Out:
# 205

# %%
df_test = fd_barnet.copy()
df_test.drop(df_test[df_test['Crime type'] != 'Burglary'].index, inplace=True)
