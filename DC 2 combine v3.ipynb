# %%
import pandas as pd
import csv
import glob

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('C:/Users/20213338/Documents/uni/Jaar2/Q4/DC 2/data_2010_to_2023/'+'*.csv')])
df
# Out:
#                                                 Crime ID    Month  \
# 0                                                    NaN  2010-12
# 1                                                    NaN  2010-12
# 2                                                    NaN  2010-12
# 3                                                    NaN  2010-12
# 4                                                    NaN  2010-12
# ...                                                  ...      ...
# 92828  9e2cf8a9d0d86bb4f87e7d5828ff37fb3d4e8cb855e327...  2023-03
# 92829  cea2e7ccaa5c3bcf1ea20fbd4444831a7b8d0169872524...  2023-03
# 92830  cb35cc774e0d827d343f949f41068d4fc89bb81074a506...  2023-03
# 92831  1ed02666b90806fd9b57f771aaf55ef81708f095ab8605...  2023-03
# 92832  7a43685bfa1543e796c96d81b22436eab79432b5e3f46a...  2023-03
#
#                        Reported by                 Falls within  Longitude  \
# 0      Metropolitan Police Service  Metropolitan Police Service   0.145949
# ...

# %%
df_burglary = df[df['Crime type'] == 'Burglary']
df_burglary = df_burglary.reset_index(drop = True)
df_burglary
# Out:
#                                                  Crime ID    Month  \
# 0                                                     NaN  2010-12
# 1                                                     NaN  2010-12
# 2                                                     NaN  2010-12
# 3                                                     NaN  2010-12
# 4                                                     NaN  2010-12
# ...                                                   ...      ...
# 919927  400f7419cc445a8de4b2140c3153d63d99358e69aa77a9...  2023-03
# 919928  dd317e1582794d8f24562a1bde1024129a7466cb2f3993...  2023-03
# 919929  9974a1809c3da57ba717f92911e62c86b590c92d0469c2...  2023-03
# 919930  e2483074dc8848d0823d61711e9f18d8cb33f05ca4b1d9...  2023-03
# 919931  6947ac864b02c1b3ad979845b7d37c69d0ab236a6fdee2...  2023-03
#
#                         Reported by                 Falls within  Longitude  \
# 0       Metropolitan Police Service  Metropolitan Police Service   0.140619
# ...

# %%
df_burglary.dropna(subset = ['LSOA name','LSOA code'], inplace=True)

# %%
df_barnet = df_burglary.loc[df_burglary['LSOA name'].str.contains("Barnet", case=False)]
df_barnet
df_barnet = df_barnet.reset_index(drop = True)
df_barnet
df_barnet.to_csv('df_combined.csv')
